# %%
# please enable if you are using a package manager like pip or conda
# Rajiv is using uv for package management hence these are commented out
# !pip install langchain_openai
# !pip install langchain_chroma
# !pip install langchain_groq
# !pip install langchain_community
# !pip install langchain_core
# !pip install langchain_ray
# !pip install chromadb

# %%
import pandas as pd
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
from langchain_groq import ChatGroq
from langchain_community.chat_models import ChatOpenAI
from langchain.docstore.document import Document
from langchain_core.prompts import ChatPromptTemplate, PromptTemplate
from langchain_community.vectorstores import chroma
from langchain_community.llms import openai
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.docstore.document import Document
from langchain.llms import HuggingFacePipeline

# deprecated legacy library
# from langchain.embeddings import HuggingFaceEmbeddings
import ray
import os
import dask.dataframe as dd
import logging
import torch
from dotenv import load_dotenv
from langchain_huggingface import HuggingFaceEmbeddings
import chromadb
from tqdm import tqdm

# %%
logging.basicConfig(
    level=logging.INFO,  # Set the minimum level of messages to display
    format="%(asctime)s - %(levelname)s - %(message)s",
)

# %%
load_dotenv()
LOCAL_MODEL_PATH = os.getenv("LOCAL_MODEL_PATH")
HUB_MODEL_ID = os.getenv("HUB_MODEL_ID")
LOCAL_VECTOR_DB_PATH = os.getenv("LOCAL_VECTOR_DB_PATH")

# %%
logging.info(f"LOCAL_MODEL_PATH: {LOCAL_MODEL_PATH}")
logging.info(f"HUB_MODEL_ID: {HUB_MODEL_ID}")
logging.info(f"LOCAL_VECTOR_DB_PATH: {LOCAL_VECTOR_DB_PATH}")
# Out:
# 2025-09-12 14:27:20,038 - INFO - LOCAL_MODEL_PATH: ./multi-qa-MiniLM-L6-cos-v1-local
# 2025-09-12 14:27:20,039 - INFO - HUB_MODEL_ID: sentence-transformers/multi-qa-MiniLM-L6-cos-v1
# 2025-09-12 14:27:20,039 - INFO - LOCAL_VECTOR_DB_PATH: ./chroma_capstone_db_new_small

# %%
if torch.cuda.is_available():
    device = "cuda"
    logging.info("Found NVIDIA GPU, using 'cuda' as the device.")
    logging.info(f"CUDA device count: {torch.cuda.device_count()}")
elif torch.backends.mps.is_available():
    device = "mps"
    logging.info("Found Apple Silicon GPU, using 'mps' as the device.")
    logging.info(f"MPS device count: 1")
else:
    device = "cpu"
    logging.warning("No GPU found, falling back to 'cpu'. This will be slower.")
    logging.info(f"CPU device count: {torch.device_count()}")
# Out:
# 2025-09-12 14:27:20,056 - INFO - Found Apple Silicon GPU, using 'mps' as the device.
# 2025-09-12 14:27:20,056 - INFO - MPS device count: 1

# %%
df = pd.read_csv("filtered_data.csv")

# %%
print(f"data frame shape: {df.shape} \n")
print(f"data frame columns: {df.columns} \n")
# Out:
# data frame shape: (154081, 21)
#
# data frame columns: Index(['Unnamed: 0', 'BlockName', 'Category', 'Year', 'Month', 'Day', 'Crop',
#        'DistrictName', 'QueryType', 'Season', 'Sector', 'StateName',
#        'QueryText', 'KccAns', 'latitude', 'longitude', 'Disease',
#        'kcc_word_count', 'QueryText_word_count', 'Season English',
#        'BlockNamenew'],
#       dtype='object')

# %%
df.head()
# Out:
#    Unnamed: 0   BlockName Category  Year  Month  Day   Crop DistrictName  \
# 0           0        0           0  2010      6   23  Apple     ANANTNAG
# 1           1        0           0  2010      6   18  Apple    BARAMULLA
# 2          23  DACHNIPORA   Fruits  2020      7   31  Apple     ANANTNAG
# 3          24     SHOPIAN   Fruits  2020      7    2  Apple     SHUPIYAN
# 4          25      SOPORE   Fruits  2022      7    6  Apple    BARAMULLA
#
#           QueryType Season  ...          StateName  \
# 0                 0  JAYAD  ...  JAMMU AND KASHMIR
# 1                 0  JAYAD  ...  JAMMU AND KASHMIR
# 2  Plant Protection    NaN  ...  JAMMU AND KASHMIR
# 3  Plant Protection    NaN  ...  JAMMU AND KASHMIR
# 4  Plant Protection    NaN  ...  JAMMU AND KASHMIR
#
#                                            QueryText  \
# 0    control of alternaria leaf blotch in apple tree
# 1  farmer wants information about the control of ...
# 2  farmer asked the query regarding problem alter...
# 3  farmer asked the query regarding problem of al...
# 4  farmer asked a query regarding alternaria leaf...
#
#                                               KccAns latitude  longitude  \
# 0  keep 60 cm soil around trees trunks undisturde...  33.7461    75.1854
# 1  the control of alternaria leaf blotch in apple...  34.2087    74.3435
# 2  it is advised to the farmer spray one of the f...  33.7461    75.1854
# 3  -- it is advised to the farmer spray in case r...  33.6649    75.1630
# 4  fruit develop ment-iv     x 12-18 days after v...  34.2087    74.3435
#
#                   Disease kcc_word_count  QueryText_word_count  \
# 0  Alternaria_leaf_blotch              9                     8
# 1  Alternaria_leaf_blotch             19                    13
# 2  Alternaria_leaf_blotch             73                    11
# 3  Alternaria_leaf_blotch             65                    13
# 4  Alternaria_leaf_blotch             70                    12
#
#            Season English BlockNamenew
# 0  Summer Cropping Season         0
# 1  Summer Cropping Season         0
# 2                     NaN   DACHNIPORA
# 3                     NaN      SHOPIAN
# 4                     NaN       SOPORE
#
# [5 rows x 21 columns]

# %%
unique_crops = df["Crop"].unique()
print(unique_crops)
# Out:
# ['Apple' 'Coconut' 'Paddy Dhan' 'Potato' 'Tomato']

# %%
df["Crop"] = df["Crop"].replace("Paddy Dhan", "Paddy_Dhan")

# %%
categories = df["Crop"].unique()
# categories[2] = categories[2].replace("Paddy Dhan","Paddy_Dhan")
category_groups = {cat: df[df["Crop"] == cat] for cat in categories}

# %%
category_groups
# Out:
# {'Apple':       Unnamed: 0   BlockName Category  Year  Month  Day   Crop DistrictName  \
#  0              0        0           0  2010      6   23  Apple     ANANTNAG
#  1              1        0           0  2010      6   18  Apple    BARAMULLA
#  2             23  DACHNIPORA   Fruits  2020      7   31  Apple     ANANTNAG
#  3             24     SHOPIAN   Fruits  2020      7    2  Apple     SHUPIYAN
#  4             25      SOPORE   Fruits  2022      7    6  Apple    BARAMULLA
#  ...          ...         ...      ...   ...    ...  ...    ...          ...
#  5660       15872        TRAL   Fruits  2024     12   13  Apple      PULWAMA
#  5661       15873      KANGAN   Fruits  2024     12   10  Apple    GANDERBAL
#  5662       15884  DACHNIPORA   Fruits  2025      2   16  Apple     ANANTNAG
#  5663       15885      BUDGAM   Fruits  2025      2   15  Apple       BADGAM
#  5664       15886    CHADOORA   Fruits  2025      2   17  Apple       BADGAM
#
#               QueryType Season  ...          StateName  \
#  0                    0  JAYAD  ...  JAMMU AND KASHMIR
#  1                    0  JAYAD  ...  JAMMU AND KASHMIR
#  2     Plant Protection    NaN  ...  JAMMU AND KASHMIR
#  3     Plant Protection    NaN  ...  JAMMU AND KASHMIR
#  4     Plant Protection    NaN  ...  JAMMU AND KASHMIR
#  ...                ...    ...  ...                ...
#  5660  Plant Protection    NaN  ...  JAMMU AND KASHMIR
#  5661  Plant Protection    NaN  ...  JAMMU AND KASHMIR
#  5662  Plant Protection    NaN  ...  JAMMU AND KASHMIR
#  5663  Plant Protection    NaN  ...  JAMMU AND KASHMIR
#  5664  Plant Protection    NaN  ...  JAMMU AND KASHMIR
#
#                                                QueryText  \
#  0       control of alternaria leaf blotch in apple tree
#  1     farmer wants information about the control of ...
#  2     farmer asked the query regarding problem alter...
#  3     farmer asked the query regarding problem of al...
#  4     farmer asked a query regarding alternaria leaf...
#  ...                                                 ...
#  5660  regarding the woolly aphid attack in apple orc...
#  5661  regarding the woolly aphid attack in apple orc...
#  5662       regarding the woolly aphid in apple orchards
#  5663  farmer asked a query regarding woolly aphid pr...
#  5664  query regarding woolly aphid problem in apple ...
#
#                                                   KccAns latitude  longitude  \
#  0     keep 60 cm soil around trees trunks undisturde...  33.7461    75.1854
#  1     the control of alternaria leaf blotch in apple...  34.2087    74.3435
#  2     it is advised to the farmer spray one of the f...  33.7461    75.1854
#  3     -- it is advised to the farmer spray in case r...  33.6649    75.1630
#  4     fruit develop ment-iv     x 12-18 days after v...  34.2087    74.3435
#  ...                                                 ...      ...        ...
#  5660  spray chlorpyriphos  1 ml in 1litre of water o...  33.9490    75.0418
#  5661      spray chlorpyriphos  1 ml in 1 litre of water  34.2889    75.0408
#  5662  as the temperature is below 4c no spray of ins...  33.7461    75.1854
#  5663  wooly apple aphid ipm strategy some mm series ...  34.0385    74.7360
#  5664  farmer is advised not to spray in apple orchar...  34.0385    74.7360
#
#                       Disease kcc_word_count  QueryText_word_count  \
#  0     Alternaria_leaf_blotch              9                     8
#  1     Alternaria_leaf_blotch             19                    13
#  2     Alternaria_leaf_blotch             73                    11
#  3     Alternaria_leaf_blotch             65                    13
#  4     Alternaria_leaf_blotch             70                    12
#  ...                      ...            ...                   ...
#  5660            Woolly_aphid             17                     8
#  5661            Woolly_aphid              9                     8
#  5662            Woolly_aphid             35                     7
#  5663            Woolly_aphid             56                    12
#  5664            Woolly_aphid             29                     8
#
#                Season English BlockNamenew
#  0     Summer Cropping Season         0
#  1     Summer Cropping Season         0
#  2                        NaN   DACHNIPORA
#  3                        NaN      SHOPIAN
#  4                        NaN       SOPORE
#  ...                      ...          ...
#  5660                     NaN         TRAL
#  5661                     NaN       KANGAN
#  5662                     NaN   DACHNIPORA
#  5663                     NaN       BUDGAM
#  5664                     NaN     CHADOORA
#
#  [5665 rows x 21 columns],
#  'Coconut':        Unnamed: 0      BlockName          Category  Year  Month  Day     Crop  \
#  5665        15888           0                    0  2009     11   13  Coconut
#  5666        15890           0                    0  2009     12   30  Coconut
#  5667        15891           0                    0  2009     12    8  Coconut
#  5668        15893           0                    0  2009     11   12  Coconut
#  5669        15894           0                    0  2009     11   11  Coconut
#  ...           ...            ...               ...   ...    ...  ...      ...
#  13113       35925          SADAR  Plantation Crops  2024      9   21  Coconut
#  13114       35929   MAGRA HAT-II  Plantation Crops  2024     10   26  Coconut
#  13115       35931         DOMJUR  Plantation Crops  2024     11   11  Coconut
#  13116       35932   AMBALAPPUZHA  Plantation Crops  2024     11   27  Coconut
#  13117       35938  PATAN VERAVAL  Plantation Crops  2025      3   26  Coconut
#
#              DistrictName         QueryType  Season  ...    StateName  \
#  5665              KAMRUP                75  KHARIF  ...        ASSAM
#  5666            PALAKKAD                 0     NaN  ...       KERALA
#  5667            KASARGOD                75     NaN  ...       KERALA
#  5668             JAJAPUR                75  KHARIF  ...       ODISHA
#  5669            NAMAKKAL                75  KHARIF  ...    TAMILNADU
#  ...                  ...               ...     ...  ...          ...
#  13113               PURI  Plant Protection     NaN  ...       ODISHA
#  13114  SOUTH 24 PARGANAS  Plant Protection     NaN  ...  WEST BENGAL
#  13115             HOWRAH  Plant Protection     NaN  ...  WEST BENGAL
#  13116          ALAPPUZHA  Plant Protection     NaN  ...       KERALA
#  13117        Gir Somnath  Plant Protection     NaN  ...      GUJARAT
#
#                                                 QueryText  \
#  5665   asking about the control measure to control bu...
#  5666                      control for bud rot in coconut
#  5667   farmer ask about control measures of bud rot i...
#  5668                                  bud rot in coconut
#  5669                                  bud rot in coconut
#  ...                                                  ...
#  13113                              white grub in coconut
#  13114  asking about control of  white grub cockchafer...
#  13115  asking about control of white grub cockchafer ...
#  13116    asked about management of white grub in coconut
#  13117  farmer asked termitewhite grub control informa...
#
#                                                    KccAns  latitude  longitude  \
#  5665   suggested to clean the affected portion and to...  26.14690    91.2227
#  5666   recommended removal of the affected portion an...  10.78740    76.4742
#  5667   remove all affected tissue of the crown and ap...  12.49150    74.9878
#  5668                          spray coc  3gmlit of water  20.82780    86.3798
#  5669   spray copperoxychloride 25glitre of water in t...  11.30340    78.1186
#  ...                                                  ...       ...        ...
#  13113  recommended to apply chlorpyrifos dust 200gm p...  19.80760    85.8253
#  13114  -                           chlorantraniliprol...  22.17770    88.5308
#  13115             -       chlorantraniliprole          -  22.57360    88.3251
#  13116  20 ec    2     drench the soil with chlorpyrif...   9.50066    76.4124
#  13117                                                 ec  20.92980    70.7628
#
#            Disease kcc_word_count  QueryText_word_count  \
#  5665      Bud_rot             12                    12
#  5666      Bud_rot             11                     6
#  5667      Bud_rot             49                    10
#  5668      Bud_rot              5                     4
#  5669      Bud_rot              9                     4
#  ...           ...            ...                   ...
#  13113  White_grub             23                     4
#  13114  White_grub              3                    11
#  13115  White_grub              3                    11
#  13116  White_grub             14                     8
#  13117  White_grub              1                    10
#
#                  Season English   BlockNamenew
#  5665   Monsoon Cropping Season           0
#  5666                       NaN           0
#  5667                       NaN           0
#  5668   Monsoon Cropping Season           0
#  5669   Monsoon Cropping Season           0
#  ...                        ...            ...
#  13113                      NaN          SADAR
#  13114                      NaN   MAGRA HAT-II
#  13115                      NaN         DOMJUR
#  13116                      NaN   AMBALAPPUZHA
#  13117                      NaN  PATAN VERAVAL
#
#  [7453 rows x 21 columns],
#  'Paddy_Dhan':         Unnamed: 0        BlockName Category  Year  Month  Day        Crop  \
#  13118        35940         BANKHEDI  Cereals  2013      7   27  Paddy_Dhan
#  13119        35941      RAJNANDGAON  Cereals  2014      1   25  Paddy_Dhan
#  13120        35942         PANITOLA  Cereals  2015     11   10  Paddy_Dhan
#  13121        35943        MAJITHA-3  Cereals  2015      9   25  Paddy_Dhan
#  13122        35944       GIDDERBAHA  Cereals  2015      8   29  Paddy_Dhan
#  ...            ...              ...      ...   ...    ...  ...         ...
#  124722      518899       KARLAMUNDA  Cereals  2024     11    1  Paddy_Dhan
#  124723      518900  KATTUMANNARKOIL  Cereals  2024     11    1  Paddy_Dhan
#  124724      518908            KOREI  Cereals  2025      3   17  Paddy_Dhan
#  124725      518910       DINHATA-II  Cereals  2025      3   17  Paddy_Dhan
#  124726      518911            BAGDA  Cereals  2025      3    2  Paddy_Dhan
#
#               DistrictName         QueryType  Season  ...       StateName  \
#  13118         HOSHANGABAD               NaN   JAYAD  ...  MADHYA PRADESH
#  13119        RAJ NANDGAON  Plant Protection  KHARIF  ...    CHHATTISGARH
#  13120           DIBRUGARH  Plant Protection     NaN  ...           ASSAM
#  13121            AMRITSAR  Plant Protection  KHARIF  ...          PUNJAB
#  13122             MUKTSAR  Plant Protection  KHARIF  ...          PUNJAB
#  ...                   ...               ...     ...  ...             ...
#  124722          KALAHANDI  Plant Protection     NaN  ...          ODISHA
#  124723          CUDDALORE  Plant Protection     NaN  ...       TAMILNADU
#  124724            JAJAPUR  Plant Protection     NaN  ...          ODISHA
#  124725        Cooch BIHAR  Plant Protection     NaN  ...     WEST BENGAL
#  124726  NORTH 24 PARGANAS  Plant Protection     NaN  ...     WEST BENGAL
#
#                                                  QueryText  \
#  13118                 how to control of armyworm in peddy
#  13119                            armyworm adults in paddy
#  13120                      asking for control of armyworm
#  13121   information regarding for the control of fall ...
#  13122   information regarding for the control of armyw...
#  ...                                                   ...
#  124722    yellowing of leaf due to tungro virus infection
#  124723  asked about rice tungro virus identification i...
#  124724                         rice tungro virus in paddy
#  124725      asking about control of tungro virus in paddy
#  124726      asking about control of tungro virus in paddy
#
#                                                     KccAns latitude  longitude  \
#  13118    foret 10 kg acre to control of armyworm in peddy  22.7546    77.7198
#  13119                                      use light trap  21.6637    81.8406
#  13120   recommended him to apply malathion 5 dust at s...  27.4845    94.9019
#  13121   information regarding for the control of fall ...  31.6357    74.8787
#  13122   for the control of armyworm in wheat cropspray...  30.4692    74.5182
#  ...                                                   ...      ...        ...
#  124722  recommended to spray mancozeb 75  wp  500 gm p...  19.8266    83.0409
#  124723  :          :  6   1 tamlaril 10   140    10   ...  11.5202    79.3396
#  124724  advised to wait some days as recently spray in...  20.8278    86.3798
#  124725            spray   fipronil 5  sc  1mllit of water  26.3224    89.4592
#  124726  spray acephate 50  imidacloprid 18 518 sp  2 g...  22.6927    88.6626
#
#                    Disease kcc_word_count  QueryText_word_count  \
#  13118       Dhan_Armyworm             10                     7
#  13119       Dhan_Armyworm              3                     4
#  13120       Dhan_Armyworm              9                     5
#  13121       Dhan_Armyworm             33                    33
#  13122       Dhan_Armyworm             20                    10
#  ...                   ...            ...                   ...
#  124722  Dhan_Tungro_virus             46                     8
#  124723  Dhan_Tungro_virus              9                     7
#  124724  Dhan_Tungro_virus             17                     5
#  124725  Dhan_Tungro_virus              7                     8
#  124726  Dhan_Tungro_virus             12                     8
#
#                   Season English     BlockNamenew
#  13118    Summer Cropping Season         BANKHEDI
#  13119   Monsoon Cropping Season      RAJNANDGAON
#  13120                       NaN         PANITOLA
#  13121   Monsoon Cropping Season        MAJITHA-3
#  13122   Monsoon Cropping Season       GIDDERBAHA
#  ...                         ...              ...
#  124722                      NaN       KARLAMUNDA
#  124723                      NaN  KATTUMANNARKOIL
#  124724                      NaN            KOREI
#  124725                      NaN       DINHATA-II
#  124726                      NaN            BAGDA
#
#  [111609 rows x 21 columns],
#  'Potato':         Unnamed: 0 BlockName    Category  Year  Month  Day    Crop  \
#  124727      518912      0              0  2009     11   18  Potato
#  124728      518913      0              0  2009     12   23  Potato
#  124729      518915      0              0  2009     12   12  Potato
#  124730      518916      0              0  2009     12   25  Potato
#  124731      518917      0              0  2009     11   14  Potato
#  ...            ...       ...         ...   ...    ...  ...     ...
#  140463      568208     SAKIT  Vegetables  2025      1    1  Potato
#  140464      568210    TARBHA  Vegetables  2025      2    3  Potato
#  140465      568211     BOUDH  Vegetables  2025      2    2  Potato
#  140466      568212    JATARA  Vegetables  2025      3   13  Potato
#  140467      568213   NUAPADA  Vegetables  2025      3    6  Potato
#
#         DistrictName         QueryType  Season  ...          StateName  \
#  124727        JAMMU                 3  KHARIF  ...  JAMMU AND KASHMIR
#  124728       SANGLI                 3   JAYAD  ...        MAHARASHTRA
#  124729     BHATINDA                 3  KHARIF  ...             PUNJAB
#  124730      BARNALA                 3  KHARIF  ...             PUNJAB
#  124731        NADIA                 3     NaN  ...        WEST BENGAL
#  ...             ...               ...     ...  ...                ...
#  140463         ETAH  Plant Protection     NaN  ...      UTTAR PRADESH
#  140464      SONEPUR  Plant Protection     NaN  ...             ODISHA
#  140465        BAUDH  Plant Protection     NaN  ...             ODISHA
#  140466    TIKAMGARH  Plant Protection     NaN  ...     MADHYA PRADESH
#  140467     NAWAPARA  Plant Protection     NaN  ...             ODISHA
#
#                                                  QueryText  \
#  124727  farmer wants information about the control of ...
#  124728                                   aphids in potato
#  124729  information regarding control of aphids in potato
#  124730  information regarding control of aphids in potato
#  124731                        control of aphids in potato
#  ...                                                   ...
#  140463  provide information regarding white grub pest ...
#  140464                   white grub infestation in potato
#  140465                              white grubs in potato
#  140466  farmer wants information about control of whit...
#  140467                 tuber rot and white grub in potato
#
#                                                     KccAns latitude  longitude  \
#  124727             spray endosulfan 35ec  2 mllt of water  32.7186    74.8581
#  124728  spray 5ml imidacloprid  30ml azadirachtin in 1...  17.1727    74.5868
#  124729  i told the kisan spray  400 ml of rogor 30 ec ...  30.2068    74.9464
#  124730   spray 300ml of gogor 30ec in 100lit of wateracre  30.3717    75.5040
#  124731                  spray dimethoate  2 mllt of water  23.4847    88.5567
#  ...                                                   ...      ...        ...
#  140463                          - carbofuran 3gr - 8 - 10  27.5550    78.5992
#  140464  recommended to set up light trap and spray ind...  20.8454    83.9091
#  140465  recommended to spray dhanulux quinalphos 25 ec...  20.8416    84.3213
#  140466      04 ww gr  4                             20 ec  24.8552    79.0473
#  140467  recommended to drench the root zone with chlor...  21.1447    82.9432
#
#             Disease kcc_word_count  QueryText_word_count  \
#  124727      Aphids              7                    10
#  124728      Aphids             10                     3
#  124729      Aphids             16                     7
#  124730      Aphids              9                     7
#  124731      Aphids              6                     5
#  ...            ...            ...                   ...
#  140463  White_grub              7                    10
#  140464  White_grub             35                     5
#  140465  White_grub             20                     4
#  140466  White_grub              6                    11
#  140467  White_grub             25                     7
#
#                   Season English BlockNamenew
#  124727  Monsoon Cropping Season         0
#  124728   Summer Cropping Season         0
#  124729  Monsoon Cropping Season         0
#  124730  Monsoon Cropping Season         0
#  124731                      NaN         0
#  ...                         ...          ...
#  140463                      NaN        SAKIT
#  140464                      NaN       TARBHA
#  140465                      NaN        BOUDH
#  140466                      NaN       JATARA
#  140467                      NaN      NUAPADA
#
#  [15741 rows x 21 columns],
#  'Tomato':         Unnamed: 0    BlockName    Category  Year  Month  Day    Crop  \
#  140468      568214         0              0  2009      5    3  Tomato
#  140469      568215         0              0  2009      4   11  Tomato
#  140470      568217         0              0  2009      6    8  Tomato
#  140471      568218         0              0  2009      6   18  Tomato
#  140472      568220         0              0  2009      1   20  Tomato
#  ...            ...          ...         ...   ...    ...  ...     ...
#  154076      602352  Channapanta  Vegetables  2024      8   22  Tomato
#  154077      602358       BASERI  Vegetables  2024     12    6  Tomato
#  154078      602360       TARBHA  Vegetables  2024     12   15  Tomato
#  154079      602361        BASSI  Vegetables  2025      3   12  Tomato
#  154080      602362        BASSI  Vegetables  2025      3   12  Tomato
#
#         DistrictName         QueryType  Season  ...          StateName  \
#  140468      PULWAMA                29   JAYAD  ...  JAMMU AND KASHMIR
#  140469       BADGAM                29  KHARIF  ...  JAMMU AND KASHMIR
#  140470       BADGAM                29   JAYAD  ...  JAMMU AND KASHMIR
#  140471       BADGAM                29   JAYAD  ...  JAMMU AND KASHMIR
#  140472        JAMMU                29  KHARIF  ...  JAMMU AND KASHMIR
#  ...             ...               ...     ...  ...                ...
#  154076   RAMANAGARA  Plant Protection     NaN  ...          KARNATAKA
#  154077     DHAULPUR  Plant Protection     NaN  ...          RAJASTHAN
#  154078      SONEPUR  Plant Protection     NaN  ...             ODISHA
#  154079       JAIPUR  Plant Protection     NaN  ...          RAJASTHAN
#  154080       JAIPUR  Plant Protection     NaN  ...          RAJASTHAN
#
#                                                  QueryText  \
#  140468      farmer wants to control over aphids in tomato
#  140469  how to control aphids in thge seedlings of tomato
#  140470  information about the control of aphids in tomato
#  140471  information regarding control of aphids in tomato
#  140472                   control of aphids in tomato crop
#  ...                                                   ...
#  154076  asked about control measures for whiteflies in...
#  154077  asked about to  whiteflies insect control in t...
#  154078  can use admire insecticide for whiteflies in t...
#  154079  asked about to whiteflies insect control in to...
#  154080  asked about to whiteflies insect control in to...
#
#                                                     KccAns latitude  longitude  \
#  140468  spray with endosulfan 35ec  3ml in 1litre of w...  33.9490    75.0418
#  140469    spray melathion 50 ec  1 ml in 1 liter of water  34.0385    74.7360
#  140470         spray with endosulfan 35 ec 2mllt of water  34.0385    74.7360
#  140471           spray malathion 35ec  25mllitre of water  34.0385    74.7360
#  140472             spray metasystox 25ec 2-3mllt of water  32.7186    74.8581
#  ...                                                   ...      ...        ...
#  154076  suggested to spray fipronil 40  imidacloprid 4...  12.7200    77.3184
#  154077  pyriproxyfen 10 ec   or   pyriproxyfen 10   bi...  26.6530    77.6241
#  154078  yes you use admire insecticide imidacloprid 70...  20.8454    83.9091
#  154079  50 whiteflies aphidsthrips jassidsdiamond back...  26.9155    75.8190
#  154080  firpronil 10  diafenthiuron 30 wgwhiteflies ap...  26.9155    75.8190
#
#             Disease kcc_word_count  QueryText_word_count  \
#  140468      Aphids              9                     8
#  140469      Aphids             11                     9
#  140470      Aphids              8                     8
#  140471      Aphids              6                     7
#  140472      Aphids              6                     6
#  ...            ...            ...                   ...
#  154076  Whiteflies             53                     8
#  154077  Whiteflies             17                     9
#  154078  Whiteflies             22                     8
#  154079  Whiteflies             10                     9
#  154080  Whiteflies             16                     9
#
#                   Season English BlockNamenew
#  140468   Summer Cropping Season         0
#  140469  Monsoon Cropping Season         0
#  140470   Summer Cropping Season         0
#  140471   Summer Cropping Season         0
#  140472  Monsoon Cropping Season         0
#  ...                         ...          ...
#  154076                      NaN  Channapanta
#  154077                      NaN       BASERI
#  154078                      NaN       TARBHA
#  154079                      NaN        BASSI
#  154080                      NaN        BASSI
#
#  [13613 rows x 21 columns]}

# %%
df = df.rename(columns={"Season English": "Season_English"})

# %%
if os.path.isdir(LOCAL_MODEL_PATH):
    logging.info(f"✅ Loading model from local path: {LOCAL_MODEL_PATH}")
    model_to_use = LOCAL_MODEL_PATH
else:
    logging.warning(
        f"⚠️ Local model not found at {LOCAL_MODEL_PATH}. Downloading from Hub: {HUB_MODEL_ID}"
    )
    # !uv add "huggingface_hub[cli]"
    # !hf download BAAI/bge-large-en-v1.5 --local-dir ./bge-large-en-v1.5-local
    # !hf download {HUB_MODEL_ID} --local-dir {LOCAL_MODEL_PATH}
    model_to_use = LOCAL_MODEL_PATH
    # model_to_use = HUB_MODEL_ID

embedding = None
try:
    embedding = HuggingFaceEmbeddings(
        model_name=model_to_use, model_kwargs={"device": device}
    )
    logging.info("Embedding model loaded successfully.")
except Exception as e:
    logging.error(f"Failed to load embedding model: {e}")
    embedding = None
logging.info(f"embedding: {embedding}")
# Out:
# 2025-09-12 14:27:21,587 - WARNING - ⚠️ Local model not found at ./multi-qa-MiniLM-L6-cos-v1-local. Downloading from Hub: sentence-transformers/multi-qa-MiniLM-L6-cos-v1
# Resolved 223 packages in 3ms
# Audited 202 packages in 0.03ms
# Fetching 29 files:   0%|                                 | 0/29 [00:00<?, ?it/s]Downloading 'model.safetensors' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/xGOKKLRSlIhH692hSVvI1-gpoa8=.7bec4fd9eba43073d5c5dcf1b79b0a3397608fa063e6f626d6f8fd70a81f2d8c.incomplete'
# Downloading 'data_config.json' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/x2Rt2861-Bgu_eYvy93NIBMPOFg=.a3294881c9834ac6fb99d420008f30b741fe7e86.incomplete'
# Downloading '1_Pooling/config.json' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/1_Pooling/8_PA_wEVGiVa2goH2H4KQOQpvVY=.d1514c3162bbe87b343f565fadc62e6c06f04f03.incomplete'
# Downloading '.gitattributes' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/wPaCkH-WbT7GsmxMKKrNZTV4nSM=.8d1395b12188a31e8a22acea211f312d818744e9.incomplete'
#
# data_config.json: 25.5kB [00:00, 142MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/data_config.json
#
# config.json: 100%|█████████████████████████████| 190/190 [00:00<00:00, 2.84MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/1_Pooling/config.json
# Downloading 'config_sentence_transformers.json' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/7FlMl4FxR6n7kBtLngDIJQ5nHiI=.fd1b291129c607e5d49799f87cb219b27f98acdf.incomplete'
#
# config_sentence_transformers.json: 100%|███████| 116/116 [00:00<00:00, 2.27MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/config_sentence_transformers.json
#
# .gitattributes: 100%|██████████████████████████| 791/791 [00:00<00:00, 13.7MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/.gitattributes
# Fetching 29 files:   3%|▊                        | 1/29 [00:00<00:10,  2.60it/s]Downloading 'README.md' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/Xn7B-BWUGOee2Y6hCZtEhtFu4BE=.49291b15aecddcea5f99be93dde87cbfdfb3127b.incomplete'
#
# README.md: 11.6kB [00:00, 43.1MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/README.md
#
# model.safetensors:   0%|                            | 0.00/90.9M [00:00<?, ?B/s]Downloading 'onnx/model.onnx' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/onnx/ihhw_uFzBe-Y54_HOJQmXx4GS8A=.826501e8460f6e1a83fa30a9b173f051100abda5559e1352efc0e3fe3136afc2.incomplete'
# Downloading 'onnx/model_O1.onnx' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/onnx/Jz1dqTRkC9OqrRVBoUUgJasE5D4=.a4f1223dea8abfca2d8ca542d7745c193d572e1673425563974d68b73048416e.incomplete'
# Downloading 'onnx/model_O2.onnx' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/onnx/fhmtN5lr2pRcTsN4JIXHvpvTfsQ=.0eca0acdebe200858d910223bd82f80dee7dbeb297e8ad002fa11c13deef4a06.incomplete'
# Downloading 'onnx/model_O4.onnx' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/onnx/8M5G_GF35MrvaVa65iMMHJv3fIA=.e7f3b68bbe14d47bdab18ba4e81ad52763517c666a3c58e3f34d2374581cd8b1.incomplete'
# Downloading 'modules.json' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/rqDUs8AfQpUqG2NjnkGNseO9-Z4=.952a9b81c0bfd99800fabf352f69c7ccd46c5e43.incomplete'
# Downloading 'config.json' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/8_PA_wEVGiVa2goH2H4KQOQpvVY=.72b987fd805cfa2b58c4c8c952b274a11bfd5a00.incomplete'
#
#
# modules.json: 100%|████████████████████████████| 349/349 [00:00<00:00, 7.96MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/modules.json
#
#
# config.json: 100%|█████████████████████████████| 612/612 [00:00<00:00, 16.9MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/config.json
# Fetching 29 files:  14%|███▍                     | 4/29 [00:00<00:04,  5.18it/s]
#
# onnx/model_O1.onnx:   0%|                           | 0.00/90.4M [00:00<?, ?B/s]
#
#
# onnx/model_O2.onnx:   0%|                           | 0.00/90.3M [00:00<?, ?B/s]
#
#
#
# onnx/model.onnx:   0%|                              | 0.00/90.4M [00:00<?, ?B/s]
#
#
#
#
# onnx/model_O4.onnx:   0%|                           | 0.00/45.2M [00:00<?, ?B/s]Downloading 'onnx/model_qint8_arm64.onnx' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/onnx/XSZ-efieuvtPx3j1uS5YppO_UUo=.89779550529b9077685f44c041cb6d5f5ce394fae8937f91d1b3a8acc675beb6.incomplete'
# Downloading 'onnx/model_qint8_avx512.onnx' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/onnx/vkIANGfBQsH4ABb2nI_WlgN4dn4=.89779550529b9077685f44c041cb6d5f5ce394fae8937f91d1b3a8acc675beb6.incomplete'
# Downloading 'onnx/model_O3.onnx' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/onnx/C5VJXYd7xfrcGI6qO6pWSgfb2iA=.3c965811fcb029c011381fde1b2cc3ba279a37f5146016e5f3852159002ad4ce.incomplete'
#
#
#
#
#
#
# onnx/model_qint8_arm64.onnx:   0%|                  | 0.00/23.0M [00:00<?, ?B/s]
#
#
#
#
#
#
# onnx/model_qint8_avx512.onnx:   0%|                 | 0.00/23.0M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# onnx/model_O3.onnx:   0%|                           | 0.00/90.3M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# onnx/model_O3.onnx:   9%|█▋                | 8.44M/90.3M [00:02<00:21, 3.73MB/s]
#
# onnx/model_O1.onnx:  26%|████▋             | 23.3M/90.4M [00:03<00:11, 5.83MB/s]
#
#
# onnx/model_O2.onnx:   9%|█▋                | 8.26M/90.3M [00:04<00:40, 2.03MB/s]
#
#
# onnx/model_O2.onnx:  18%|███▎              | 16.7M/90.3M [00:05<00:21, 3.41MB/s]
#
#
#
# onnx/model.onnx:  26%|█████▍               | 23.4M/90.4M [00:05<00:16, 4.11MB/s]
#
#
# onnx/model_O2.onnx:  44%|███████▉          | 40.0M/90.3M [00:06<00:05, 9.09MB/s]
#
#
#
#
#
#
#
# onnx/model_O3.onnx:  18%|███▎              | 16.7M/90.3M [00:05<00:26, 2.77MB/s]
#
#
#
#
#
#
# onnx/model_qint8_avx512.onnx: 100%|████████| 23.0M/23.0M [00:06<00:00, 3.69MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/onnx/model_qint8_avx512.onnx
# Downloading 'onnx/model_qint8_avx512_vnni.onnx' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/onnx/WpaTElq6uGDhP7vAplvKxvF90ek=.89779550529b9077685f44c041cb6d5f5ce394fae8937f91d1b3a8acc675beb6.incomplete'
#
#
#
# onnx/model_O2.onnx:  54%|█████████▋        | 48.5M/90.3M [00:07<00:04, 8.67MB/s]
#
#
#
#
#
#
# onnx/model_qint8_avx512_vnni.onnx:   0%|            | 0.00/23.0M [00:00<?, ?B/s]
#
#
#
#
#
#
#
# onnx/model_O3.onnx:  37%|██████▋           | 33.4M/90.3M [00:06<00:09, 5.91MB/s]
#
#
#
#
#
#
#
# onnx/model_O3.onnx:  46%|████████▎         | 41.8M/90.3M [00:06<00:06, 8.01MB/s]
#
#
#
#
#
#
#
# onnx/model_O3.onnx:  74%|█████████████▎    | 67.0M/90.3M [00:07<00:01, 16.7MB/s]
#
#
#
#
#
#
# onnx/model_qint8_avx512_vnni.onnx: 100%|███| 23.0M/23.0M [00:00<00:00, 29.0MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/onnx/model_qint8_avx512_vnni.onnx
#
#
#
#
#
#
#
#
# onnx/model_O3.onnx: 100%|██████████████████| 90.3M/90.3M [00:07<00:00, 11.9MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/onnx/model_O3.onnx
# Downloading 'onnx/model_quint8_avx2.onnx' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/onnx/DkWusgf06FSZDVV1Q4a480SyGlg=.773212b274aa3b5c3f388e32d6514c1ed000f31074d46d957a08c6e352fe1064.incomplete'
#
#
#
# onnx/model_O2.onnx: 100%|██████████████████| 90.3M/90.3M [00:08<00:00, 10.7MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/onnx/model_O2.onnx
# Downloading 'openvino/openvino_model.bin' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/openvino/SAxurrcy-4m-l5PAwlLF8JFD92I=.89f9ad00a782cba3234270239daec47a1067b63399b512c1b7c622214d639c35.incomplete'
#
#
#
# onnx/model_quint8_avx2.onnx:   0%|                  | 0.00/23.0M [00:00<?, ?B/s]Downloading 'openvino/openvino_model.xml' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/openvino/RHtQiE8mUsJXT1ACniRNFX2H1R4=.065b86b2315d820a9c3ba3e20966308dcce8dafd.incomplete'
#
#
#
#
#
#
#
# openvino_model.xml: 0.00B [00:00, ?B/s]
#
#
#
#
#
#
#
# openvino_model.xml: 212kB [00:00, 6.10MB/s]         | 0.00/90.3M [00:00<?, ?B/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/openvino/openvino_model.xml
#
#
# onnx/model_O1.onnx: 100%|██████████████████| 90.4M/90.4M [00:08<00:00, 10.1MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/onnx/model_O1.onnx
# Downloading 'openvino/openvino_model_qint8_quantized.bin' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/openvino/5sXxy3T6xtaD5oz1H_aX4KjEPgQ=.a7ca78e428d963e69b7cb9c948cdc8af1a3e319f0cd3a4882a7f2b49153ec563.incomplete'
# Downloading 'openvino/openvino_model_qint8_quantized.xml' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/openvino/QnL_Hg8_Eqaf3xzWBW1kwNT1rMU=.c9ff85c878c8f436dc5902467165bab4fd7288a4.incomplete'
#
#
# openvino_model_qint8_quantized.xml: 368kB [00:00, 14.0MB/s][A
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/openvino/openvino_model_qint8_quantized.xml
#
#
# openvino/openvino_model_qint8_quantized.(…):   0%|  | 0.00/22.9M [00:00<?, ?B/s]
#
#
#
#
#
# onnx/model_qint8_arm64.onnx: 100%|█████████| 23.0M/23.0M [00:09<00:00, 2.53MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/onnx/model_qint8_arm64.onnx
#
#
#
#
#
# onnx/model_O4.onnx: 100%|██████████████████| 45.2M/45.2M [00:09<00:00, 4.71MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/onnx/model_O4.onnx
# Downloading 'pytorch_model.bin' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/Q1p2l2BzM1m6P5jKvr8WTq1TUio=.df507ec1743de52aa0a1b401183c5fd8ca18e846689421ea6c94cae014d9b26b.incomplete'
# Downloading 'sentence_bert_config.json' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/lGVMDuXJ-eOxWaZOviD6MtO-75w=.f789d99277496b282d19020415c5ba9ca79ac875.incomplete'
#
# model.safetensors:  26%|████▉              | 23.8M/90.9M [00:10<00:28, 2.34MB/s]
#
#
#
#
# sentence_bert_config.json: 100%|██████████████| 53.0/53.0 [00:00<00:00, 984kB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/sentence_bert_config.json
#
#
#
#
#
# pytorch_model.bin:   0%|                            | 0.00/90.9M [00:00<?, ?B/s]Downloading 'special_tokens_map.json' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/ahkChHUJFxEmOdq5GDFEmerRzCY=.e7b0375001f109a6b8873d756ad4f7bbb15fbaa5.incomplete'
#
#
#
#
#
#
# special_tokens_map.json: 100%|█████████████████| 112/112 [00:00<00:00, 2.67MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/special_tokens_map.json
# Downloading 'tokenizer.json' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/HgM_lKo9sdSCfRtVg7MMFS7EKqo=.9c190aac0fb9edc2293b69b82c6d5d5d21e67dd9.incomplete'
#
#
#
#
#
#
# tokenizer.json: 466kB [00:00, 7.86MB/s][A
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/tokenizer.json
#
#
#
#
#
#
#
#
# openvino/openvino_model.bin:   9%|▊        | 8.16M/90.3M [00:01<00:15, 5.21MB/s]Downloading 'tf_model.h5' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/a7eHxRFT3OeMBIFg52k2nfj5m7w=.d356e3a2867336eb0c469be0151e1edf79666e6399dd050a4c382e3c407432a2.incomplete'
#
#
#
#
# onnx/model.onnx: 100%|█████████████████████| 90.4M/90.4M [00:10<00:00, 8.69MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/onnx/model.onnx
#
#
#
#
#
#
#
#
# openvino/openvino_model.bin:  49%|████▍    | 44.0M/90.3M [00:01<00:01, 32.9MB/s]Downloading 'tokenizer_config.json' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/vzaExXFZNBay89bvlQv-ZcI6BTg=.d50701956f8e35e7507e6b74547a71e62ca39cad.incomplete'
#
#
#
#
# tf_model.h5:   0%|                                  | 0.00/91.0M [00:00<?, ?B/s]
#
#
#
#
#
# tokenizer_config.json: 100%|███████████████████| 383/383 [00:00<00:00, 8.15MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/tokenizer_config.json
# Downloading 'train_script.py' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/WVoL7XhpU3FxrnFpNM2RbMmfULg=.131d011c947fb9e8994a79f40d0325bd10daa858.incomplete'
#
#
#
#
#
#
# train_script.py: 13.8kB [00:00, 71.3MB/s]A
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/train_script.py
#
#
#
#
#
# pytorch_model.bin:   1%|▏                    | 578k/90.9M [00:00<02:13, 678kB/s]Downloading 'vocab.txt' to 'multi-qa-MiniLM-L6-cos-v1-local/.cache/huggingface/download/E2zehc7lrIVb8gRdx7qjK54iiZY=.fb140275c155a9c7c5a3b3e0e77a9e839594a938.incomplete'
#
#
#
#
#
#
# vocab.txt: 0.00B [00:00, ?B/s]
#
#
#
#
#
#
#
# vocab.txt: 232kB [00:00, 10.6MB/s]██████   | 60.4M/90.3M [00:02<00:01, 28.4MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/vocab.txt
#
#
#
# onnx/model_quint8_avx2.onnx: 100%|█████████| 23.0M/23.0M [00:02<00:00, 8.87MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/onnx/model_quint8_avx2.onnx
#
#
# openvino/openvino_model_qint8_quantized.(…): 100%|█| 22.9M/22.9M [00:02<00:00, 1
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/openvino/openvino_model_qint8_quantized.bin
#
#
#
#
# tf_model.h5:   0%|                           | 201k/91.0M [00:01<08:49, 171kB/s]
#
#
#
#
# pytorch_model.bin: 100%|███████████████████| 90.9M/90.9M [00:02<00:00, 40.3MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/pytorch_model.bin
#
#
#
#
#
#
#
#
# openvino/openvino_model.bin:  97%|████████▊| 88.0M/90.3M [00:03<00:00, 25.0MB/s]
# model.safetensors: 100%|███████████████████| 90.9M/90.9M [00:13<00:00, 6.96MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/model.safetensors
# Fetching 29 files:  24%|██████                   | 7/29 [00:13<00:52,  2.39s/it]
#
#
#
# tf_model.h5: 100%|█████████████████████████| 91.0M/91.0M [00:02<00:00, 36.5MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/tf_model.h5
# openvino/openvino_model.bin: 100%|█████████| 90.3M/90.3M [00:04<00:00, 20.4MB/s]
# Download complete. Moving file to multi-qa-MiniLM-L6-cos-v1-local/openvino/openvino_model.bin
# Fetching 29 files: 100%|████████████████████████| 29/29 [00:14<00:00,  2.04it/s]
# /Users/rajranja/Documents/github/cds-9-group-6/sasya-chikitsa/vector-database/multi-qa-MiniLM-L6-cos-v1-local
# 2025-09-12 14:27:38,135 - INFO - Load pretrained SentenceTransformer: ./multi-qa-MiniLM-L6-cos-v1-local
# 2025-09-12 14:27:38,242 - INFO - Embedding model loaded successfully.
# 2025-09-12 14:27:38,243 - INFO - embedding: model_name='./multi-qa-MiniLM-L6-cos-v1-local' cache_folder=None model_kwargs={'device': 'mps'} encode_kwargs={} query_encode_kwargs={} multi_process=False show_progress=False

# %% [markdown]
# #### Renaming the calender names

# %%
import calendar

month_number = 3
month_name = calendar.month_name[month_number]

# %%
df["Month"] = df["Month"].apply(lambda x: calendar.month_name[x])
df["Month"][:5]
# Out:
# 0    June
# 1    June
# 2    July
# 3    July
# 4    July
# Name: Month, dtype: object

# %%
df[df["Crop"] == "Tomato"].head(5)
# Out:
#         Unnamed: 0 BlockName Category  Year    Month  Day    Crop  \
# 140468      568214      0           0  2009      May    3  Tomato
# 140469      568215      0           0  2009    April   11  Tomato
# 140470      568217      0           0  2009     June    8  Tomato
# 140471      568218      0           0  2009     June   18  Tomato
# 140472      568220      0           0  2009  January   20  Tomato
#
#        DistrictName QueryType  Season  ...          StateName  \
# 140468      PULWAMA        29   JAYAD  ...  JAMMU AND KASHMIR
# 140469       BADGAM        29  KHARIF  ...  JAMMU AND KASHMIR
# 140470       BADGAM        29   JAYAD  ...  JAMMU AND KASHMIR
# 140471       BADGAM        29   JAYAD  ...  JAMMU AND KASHMIR
# 140472        JAMMU        29  KHARIF  ...  JAMMU AND KASHMIR
#
#                                                 QueryText  \
# 140468      farmer wants to control over aphids in tomato
# 140469  how to control aphids in thge seedlings of tomato
# 140470  information about the control of aphids in tomato
# 140471  information regarding control of aphids in tomato
# 140472                   control of aphids in tomato crop
#
#                                                    KccAns latitude  longitude  \
# 140468  spray with endosulfan 35ec  3ml in 1litre of w...  33.9490    75.0418
# 140469    spray melathion 50 ec  1 ml in 1 liter of water  34.0385    74.7360
# 140470         spray with endosulfan 35 ec 2mllt of water  34.0385    74.7360
# 140471           spray malathion 35ec  25mllitre of water  34.0385    74.7360
# 140472             spray metasystox 25ec 2-3mllt of water  32.7186    74.8581
#
#         Disease kcc_word_count  QueryText_word_count           Season_English  \
# 140468   Aphids              9                     8   Summer Cropping Season
# 140469   Aphids             11                     9  Monsoon Cropping Season
# 140470   Aphids              8                     8   Summer Cropping Season
# 140471   Aphids              6                     7   Summer Cropping Season
# 140472   Aphids              6                     6  Monsoon Cropping Season
#
#        BlockNamenew
# 140468         0
# 140469         0
# 140470         0
# 140471         0
# 140472         0
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Loading data to vector database

# %%
category_groups = {cat: df[df["Crop"] == cat] for cat in categories}

# %%
# chromadb.api.client.SharedSystemClient.clear_system_cache()

# %%
# Store documents per category
for cat, df_cat in tqdm(category_groups.items(), desc="Processing categories"):
    print(len(df_cat))
    docs = [
        Document(
            page_content=f"DistrictName:{row['DistrictName']}\nStateName:{row['StateName']}\nSeason_English:{row['Season_English']}\nMonth:{row['Month']}\nDisease:{row['Disease']}\nQueryText:{row['QueryText']}\nKccAns:{row['KccAns']}",
            metadata={"category": cat},
        )
        for _, row in df_cat.iterrows()
    ]

    chroma_collection = Chroma.from_documents(
        docs,
        embedding=embedding,
        persist_directory=LOCAL_VECTOR_DB_PATH,
        collection_name=cat,
    )

    # chroma_collection.persist()
# Out:
# Processing categories:   0%|          | 0/5 [00:00<?, ?it/s]2025-09-12 14:27:59,926 - INFO - Anonymized telemetry enabled. See                     https://docs.trychroma.com/telemetry for more information.
# 5665
# Processing categories:  20%|██        | 1/5 [00:07<00:29,  7.30s/it]
# 7453
# Processing categories:  40%|████      | 2/5 [00:15<00:23,  7.74s/it]
# 111609
# Processing categories:  60%|██████    | 3/5 [01:57<01:41, 50.83s/it]
# 15741
# Processing categories:  80%|████████  | 4/5 [02:11<00:36, 36.14s/it]
# 13613
# Processing categories: 100%|██████████| 5/5 [02:22<00:00, 28.46s/it]

# %%
chroma_db = Chroma(
    persist_directory=LOCAL_VECTOR_DB_PATH,
    embedding_function=embedding,
    collection_name="Tomato",  # Specify which collection to load
)

# %%
print(chroma_db._collection.count())
# Out:
# 13613

# %%
question = "give me the cure for tomato plant"
docs = chroma_db.max_marginal_relevance_search(question, k=3, fetch_k=6)

# %%
retriever = chroma_db.as_retriever(
    search_type="mmr", search_kwargs={"k": 3, "fetch_k": 6}
)

# %%
docs = retriever.invoke(question)
docs
# Out:
# [Document(id='e54f6267-aae6-4534-84a9-4fb8fa303559', metadata={'category': 'Tomato'}, page_content='DistrictName:CHITTOOR\nStateName:ANDHRA PRADESH\nSeason_English:nan\nMonth:February\nDisease:Leaf_miner\nQueryText:tomato leaf miner management\nKccAns:300    200         recommended to spray novaluron 525  emamectin benzoate 09barazide 320ml200 liter of wateracre'),
#  Document(id='ba0415a0-e46c-4a2c-b38b-ead221767478', metadata={'category': 'Tomato'}, page_content='DistrictName:KEONJHAR\nStateName:ODISHA\nSeason_English:nan\nMonth:February\nDisease:Leaf_miner\nQueryText:leaf miner in tomato\nKccAns:recommended to spray copper oxychloride 50wp  500gm  plantomycin  200gm with 200 liter of water per acre for prevention of root rot in tomato'),
#  Document(id='2ec5ed39-7b5f-4e74-8a0b-6f254acc8272', metadata={'category': 'Tomato'}, page_content='DistrictName:WARANGAL RURAL\nStateName:TELANGANA\nSeason_English:nan\nMonth:December\nDisease:Fruit_borer\nQueryText:tomato fruit borer management -\nKccAns:recommended to spray emamectin benzoate  90 grams 150 litres of water  acre  orrecommended to spray chlorantraniliprole 60 ml 200 litres of water  acre')]

# %% [markdown]
# ### Performance test the chromadb on the embedding model that we are using

# %%
import time
from collections import deque
from datetime import datetime


class ChromaDBPerformanceMonitor:
    """
    Real-time performance monitoring for ChromaDB queries
    """

    def __init__(self, window_size=100):
        self.window_size = window_size
        self.query_times = deque(maxlen=window_size)
        self.query_history = []

    def timed_query(self, retriever, question, metadata=None):
        """
        Execute query with timing and store results
        """
        timestamp = datetime.now()
        start_time = time.perf_counter()

        docs = retriever.invoke(question)

        end_time = time.perf_counter()
        query_time = end_time - start_time

        # Store timing data
        self.query_times.append(query_time)

        query_record = {
            "timestamp": timestamp,
            "question": question,
            "query_time": query_time,
            "doc_count": len(docs),
            "metadata": metadata or {},
        }
        self.query_history.append(query_record)

        return docs, query_record

    def get_stats(self):
        """
        Get current performance statistics
        """
        if not self.query_times:
            return None

        recent_times = list(self.query_times)

        stats = {
            "total_queries": len(self.query_history),
            "recent_queries": len(recent_times),
            "avg_time": sum(recent_times) / len(recent_times),
            "min_time": min(recent_times),
            "max_time": max(recent_times),
            "queries_per_second": 1 / (sum(recent_times) / len(recent_times)),
            "last_query_time": recent_times[-1] if recent_times else None,
        }

        return stats

    def print_stats(self):
        """
        Print current performance statistics
        """
        stats = self.get_stats()
        if not stats:
            print("No queries executed yet")
            return

        print(
            f"\n📈 ChromaDB Performance Stats (last {stats['recent_queries']} queries)"
        )
        print("-" * 50)
        print(f"Average query time: {stats['avg_time']:.4f}s")
        print(f"Fastest query: {stats['min_time']:.4f}s")
        print(f"Slowest query: {stats['max_time']:.4f}s")
        print(f"Queries per second: {stats['queries_per_second']:.2f}")
        print(f"Total queries: {stats['total_queries']}")

# %%
# Usage
monitor = ChromaDBPerformanceMonitor()

# Execute queries with monitoring
questions = [
    "I dont know my state name. I have tomato plants with disease. What should I do?",
    "Coconut palm pest control",
    "Tomato disease treatment methods",
    "Paddy disease treatment methods",
    "It is summer in karnataka state. I have tomato plants with disease. What should I do?",
]

for question in questions:
    docs, record = monitor.timed_query(retriever, question)
    print(
        f"Query: {question[:40]}... ({record['query_time']:.4f}s, {record['doc_count']} docs)"
    )

# Get overall statistics
monitor.print_stats()
# Out:
# Query: I dont know my state name. I have tomato... (0.0647s, 3 docs)
# Query: Coconut palm pest control... (0.0338s, 3 docs)
# Query: Tomato disease treatment methods... (0.0085s, 3 docs)
# Query: Paddy disease treatment methods... (0.0083s, 3 docs)
# Query: It is summer in karnataka state. I have ... (0.0260s, 3 docs)
#
# 📈 ChromaDB Performance Stats (last 5 queries)
# --------------------------------------------------
# Average query time: 0.0283s
# Fastest query: 0.0083s
# Slowest query: 0.0647s
# Queries per second: 35.38
# Total queries: 5

# %% [markdown]
# ## Call the LLM to get prescription

# %%
from langchain.schema.runnable import RunnableParallel, RunnablePassthrough
from langchain_huggingface import HuggingFaceEndpoint
from langchain_core.output_parsers import StrOutputParser

# %%
# Build prompt
template = """Use the following pieces of context to answer the question at the end.
If you don't know the answer, just say that you don't know, don't try to make up an answer.
Always say "thanks for asking!" at the end of the answer.
{context}
Question: {question}
Helpful Answer:"""

QA_PROMPT = PromptTemplate(input_variables=["context", "question"], template=template)

# %%
retrieval = RunnableParallel(
    {
        "context": RunnablePassthrough(context=lambda x: x["question"] | retriever),
        "question": RunnablePassthrough(),
    }
)

# %%
from langchain_huggingface import HuggingFacePipeline

chat_llm = HuggingFacePipeline.from_model_id(
    model_id="Qwen/Qwen3-4B-Thinking-2507",
    task="text-generation",
    model_kwargs={
        # "max_new_tokens": 100,
        "top_k": 30,
        "temperature": 0.5,
        "repetition_penalty": 1.03,
    },
)
# Out:
# The following generation flags are not valid and may be ignored: ['temperature', 'top_k']. Set `TRANSFORMERS_VERBOSITY=info` for more details.
# Loading checkpoint shards:   0%|          | 0/3 [00:00<?, ?it/s]
# Device set to use mps:0

# %%
# from langchain_community.chat_models import ChatHuggingFace
from langchain_huggingface import ChatHuggingFace
from langchain.chains import RetrievalQA

# %%
llm = ChatHuggingFace(llm=chat_llm)

# %%
question = "give me the cure for tomato plant in JAMMU AND KASHMIR for Aphids"

qa_chain = RetrievalQA.from_chain_type(
    llm, retriever=chroma_db.as_retriever(), return_source_documents=True
)

result = qa_chain.invoke({"query": question})

# %%
print(result["result"])
# Out:
# <|im_start|>system
# Use the following pieces of context to answer the user's question.
# If you don't know the answer, just say that you don't know, don't try to make up an answer.
# ----------------
# DistrictName:BADGAM
# StateName:JAMMU AND KASHMIR
# Season_English:Monsoon Cropping Season
# Month:April
# Disease:Aphids
# QueryText:how to control aphids in thge seedlings of tomato
# KccAns:spray melathion 50 ec  1 ml in 1 liter of water
#
# DistrictName:JAMMU
# StateName:JAMMU AND KASHMIR
# Season_English:Summer Cropping Season
# Month:April
# Disease:Aphids
# QueryText:farmer wants information about the control of aphids in tomato
# KccAns:spray melathion  250 ml in 100 lt of wateracre
#
# DistrictName:JAMMU
# StateName:JAMMU AND KASHMIR
# Season_English:Summer Cropping Season
# Month:April
# Disease:Aphids
# QueryText:information abot the control of aphids in tomato
# KccAns:spray with endosulfan 35 ec 2mllt of water
#
# DistrictName:PULWAMA
# StateName:JAMMU AND KASHMIR
# Season_English:Summer Cropping Season
# Month:May
# Disease:Aphids
# QueryText:farmer wants to control over aphids in tomato
# KccAns:spray with endosulfan 35ec  3ml in 1litre of water<|im_end|>
# <|im_start|>user
# give me the cure for tomato plant in JAMMU AND KASHMIR for Aphids<|im_end|>
# <|im_start|>assistant
# <think>
# I need to analyze the context provided to answer the user's question about the cure for aphids in tomato plants in Jammu and Kashmir.
#
# Let me extract the relevant information from the context:
#
# 1. There are several entries for different districts in Jammu and Kashmir (BADGAM, JAMMU, PULWAMA) with information about aphids in tomato plants.
#
# 2. The user is asking for "the cure for tomato plant in JAMMU AND KASHMIR for Aphids"
#
# 3. The context provides different pesticide recommendations for controlling aphids in tomatoes:
#
# From BADGAM (April, Monsoon Cropping Season):
# - KccAns: spray melathion 50 ec 1 ml in 1 liter of water
#
# From JAMMU (April, Summer Cropping Season):
# - KccAns: spray melathion 250 ml in 100 lt of wateracre
# - KccAns: spray with endosulfan 35 ec 2ml in 1 liter of water
#
# From PULWAMA (May, Summer Cropping Season):
# - KccAns: spray with endosulfan 35 ec 3ml in 1 litre of water
#
# The user specifically asked for

# %%
import shutil

# Zip the Chroma DB folder
shutil.make_archive("chroma_capstone_db_new", 'zip', "./chroma_capstone_db_new")

# %%
from google.colab import files
files.download("chroma_capstone_db_new.zip")

# %%
category_groups.keys()
